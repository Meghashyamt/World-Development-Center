# %% [markdown]
# Step 1. Visit the World Bank website for information about the World Development Indicators
# https://datatopics.worldbank.org/world-development-indicators/
#
# Step 2. Play with the World Development Explorer (WDX) and get familar with its functionalities
#
# The WDX main page (the explorer)
# http://www.worlddev.xyz
#
# Use this page to understand the definition of each topic and its indicators
# http://www.worlddev.xyz/indicators
#
# Use this page to get familiar with regions and countries
# http://www.worlddev.xyz/countries -

# %% [markdown]
# Step 3. Think about your interests
#
# 1. Determine What Topics are interesting to you?
#
# I am interested in Economy Growth , Health and Education .
#
# 2. For each topic of your interest, explore the vast indicators
#
# Economy and Growth -GDP Per captial, PPP
#
# Health - Life Expectancy at birth (total years)
#
# Percentage of Female population 15-19 age with no education
#
# 3. Determine what countries are interesting to you
#
# India, United States, Germany, Bangladesh
#
# 4. Determine what time span you would like to cover
#
# Data span 2010 to 2020

# %% [markdown]
# Try to utilize all charts provided by WDX
# - Download the charts that are insightful
# - Taking note of your understanding of the charts
#  - what does it reveal to you?

# %%
! git clone https://github.com/Meghashyamt/World-Development-Center.git
# Out:
# Cloning into 'World-Development-Center'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), 550.60 KiB | 1.19 MiB/s, done.

# %%
# !unzip -uq "World-Development-Center/plots.zip"

# %%
from IPython.display import Image

# %%
Image(filename='newplot (3)..png')

# %% [markdown]
# 2010-Comparing with the Population Growth with the countries, Bangladesh,Germany, India and United States.
#
# In India Population Growth annually is increasing 1.3% and Bangladesh is 1.1% increasing . United states around 0.8% is increasing in population. But in Germany population rate is in decreasing rate -0.1%.

# %%
Image(filename='newplot (4)..png')

# %% [markdown]
# Life expectancy at birth for Germany is 80 years.
#
# United States around 78 years.
#
# Bangladesh is 70 years
#
# India is 68 years.
#
# India has least life expectancy compared to other countries.

# %%
Image(filename='newplot (5)..png')

# %% [markdown]
# India with GDP 7% in 2010 and in 2018 it is decreased to 5%.
#
# Bangladesh in in steady increase compared from previous year till 2018. In 2010 is from 4.3% to 2018 of 6.7% increase for Bangladesh.
#
# Germany is decreasing from 2010 till 2018 . 2010 with 4.3% GDP and sudden decrease in 2011 to 2012. And in 2018 around 1% GDP.
#
# United States it is in constant range of GDP from 2010 of 1.8 % and in 2018 of 2.3% GDP.

# %%
Image(filename='newplot (6)..png')

# %% [markdown]
# Comparing Life expectancy from 2010 to 2018 with country wise.
#
# 2010- Life Expectancy of Bangladesh from 70 years to 72 years in 2018 . Steep increase in Life Expectancy.
#
# Germany Life expectancy in 2010 is 80 years and 2018 is 82 years. Constant and as well as increase in this country.
#
# India Life expectancy in 2010 is 67 years and later on little bit increase in 2018 of 69 years.
#
# United States is like a constant format of 79 years from 2010-2018

# %%
Image(filename='newplot (1)..png')

# %% [markdown]
# Population comparing with the country wise.
#
# India has the highest population as well as GDP of less then 10k and life expectancy between 65-70 years.
#
# United states has highest GDP around 48-50k and life expectancy of 79 years.
#
# Germany population is less compared to other countries. And life expectancy is 81 years and GDP is between 38-40k.
#
# Bangladesh has less GDP compared to other countries around 1-2k and life expectancy is 70 years.

# %% [markdown]
# What is it that you are investigating/exploring/analyzing (provide sufficient background information)?
#
# Related to life expectancy , comparing the countries. And also population .

# %% [markdown]
# Why is it important to you and/or to others?
#
# Comparing health issues , impact the life expectancy.

# %% [markdown]
# What questions do you have in mind and would like to answer?
#
# Ans: Why there is life expectancy is less , and how to improve it. We can improve due to pollution reduce , healthy food .

# %% [markdown]
# Where do you get the data to help answer your questions?
#
# Based on the world development explorer, finding out the health issue and food improvement.

# %% [markdown]
# What process/step you use to analyze the situation/issue
# - You will report the findings and your analysis of each issue/question after the introduction
#
# A Problem Analysis investigates a situation/problem in order to allow the researcher to understand more fully the problem, in order to recommend practical solutions for solving it.
#
# In addition, a Problem Analysis determines the degree of the problem and if the problem is a genuinely related to the specific site under investigated.

# %% [markdown]
# You compare different countries and show similarities/differences and their implcations

# %%
Image(filename='newplot (8)..png')

# %% [markdown]
# Compared to other countries  in 2018 ,Bangladesh has the highest GDP increase of 44.6%.
#
# India is second GDP percentage of 33.2 %.
#
# United States is 15.8% GDP.
#
# And Germany is least increase of 6.38% increase in GDP.

# %%
Image(filename='newplot (10)..png')

# %% [markdown]
# Gross Domestic Product is increasing each year for India. And the population also with life expectancy is increasing also.
